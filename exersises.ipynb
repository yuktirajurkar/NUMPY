# %%
import numpy as np

# %% [markdown]
# **Valid Sudoku**

# %%
s = np.array([
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],
    
    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1],
    [7, 1, 3, 9, 2, 4, 8, 5, 6],
    
    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]
])

# %%
s.sum()
# Out:
# np.int64(405)

# %%
np.sum(s,axis=1) # to check if all rows sum equals 45. ONly then the sudoku is valid
# Out:
# array([45, 45, 45, 45, 45, 45, 45, 45, 45])

# %%
b=np.sum(s,axis=1)
for i in b:
    if i!=45:
        print("Sudoku is not valid for rows")
        break
else:
        print("Sudoku is valid for rows")
# Out:
# Sudoku is valid for rows

# %%
np.sum(s,axis=0)
# Out:
# array([45, 45, 45, 45, 45, 45, 45, 45, 45])

# %%
b=np.sum(s,axis=0) # for columns.
for i in b:
    if i!=45:
        print("Sudoku is not valid for columns")
        break
else:
        print("Sudoku is valid for columns")
# Out:
# Sudoku is valid for columns

# %%
for i in range(0,9,3):    # to check if each 3x3 blocks have sum = 45.
    for j in range(0,9,3):
        n=s[i:i+3,j:j+3]
        print(n.sum())
# Out:
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45

# %% [markdown]
# **General Questions**

# %%
import numpy as np

# Columns: [Age, Math Marks, Science Marks]
data = np.array([
    [18, 85, 78],   # Student 1
    [19, 92, 88],   # Student 2
    [17, 76, 95],   # Student 3
    [18, 65, 70],   # Student 4
    [20, 90, 85]    # Student 5
])

# %%
#Get the shape of the matrix.
data.shape
# Out:
# (5, 3)

# %%
#Find the average age of students.
np.mean(data[:,0])
# Out:
# np.float64(18.4)

# %%
#Extract Math marks of all students.
a=data[:,1]
a
# Out:
# array([85, 92, 76, 65, 90])

# %%
#Find the highest Science mark.
b=data[:,2]
np.max(b)
# Out:
# np.int64(95)

# %%
#Get details of the student who scored more than 90 in Math.
data[data[:,1]>90]
# Out:
# array([[19, 92, 88]])

# %%
#Increase Math marks of all students by 5.
data[:,1] +=5  # due to broadcasting we can directly write +5.
data
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 95],
#        [18, 70, 70],
#        [20, 95, 85]])

# %%
#Find how many students are younger than 19.
len(data[data[:,0]<19])
# Out:
# 3

# %%
#Calculate the average marks in each subject (column-wise mean).
np.mean(data[:,1:],axis=0)
# Out:
# array([86.6, 83.2])

# %%
#Get data of students who scored at least 80 in both subjects.
data[(data[:,1]>=80) & (data[:,2]>=80)]
# Out:
# array([[19, 97, 88],
#        [17, 81, 95],
#        [20, 95, 85]])

# %%
#Replace all Science marks < 75 with 0.
data[:,2][data[:,2]<75]=0 #data[:,2]- selects science column(if we don't do this it'll replace with 0 for all columns including maths and age), data[:,2]>75 checks is marks is less than 75 in science. and =0 to replace them with 0.
data
# Out:
# array([[18, 90, 78],
#        [19, 97, 88],
#        [17, 81, 95],
#        [18, 70,  0],
#        [20, 95, 85]])
